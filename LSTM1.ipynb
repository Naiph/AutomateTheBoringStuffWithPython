# %%
import keras as K
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf

# %%
import numpy as np
import pandas as pd

# %%
max_w = 100
print('loading data..')

(train_x, train_y) , (test_x, test_y) = K.datasets.imdb.load_data(num_words=max_w)
# Out:
# loading data..

# %%
print(train_x[0:5])
print(train_y[0:5])
# Out:
# [list([1, 14, 22, 16, 43, 2, 2, 2, 2, 65, 2, 2, 66, 2, 4, 2, 36, 2, 5, 25, 2, 43, 2, 2, 50, 2, 2, 9, 35, 2, 2, 5, 2, 4, 2, 2, 2, 2, 2, 2, 39, 4, 2, 2, 2, 17, 2, 38, 13, 2, 4, 2, 50, 16, 6, 2, 2, 19, 14, 22, 4, 2, 2, 2, 4, 22, 71, 87, 12, 16, 43, 2, 38, 76, 15, 13, 2, 4, 22, 17, 2, 17, 12, 16, 2, 18, 2, 5, 62, 2, 12, 8, 2, 8, 2, 5, 4, 2, 2, 16, 2, 66, 2, 33, 4, 2, 12, 16, 38, 2, 5, 25, 2, 51, 36, 2, 48, 25, 2, 33, 6, 22, 12, 2, 28, 77, 52, 5, 14, 2, 16, 82, 2, 8, 4, 2, 2, 2, 15, 2, 4, 2, 7, 2, 5, 2, 36, 71, 43, 2, 2, 26, 2, 2, 46, 7, 4, 2, 2, 13, 2, 88, 4, 2, 15, 2, 98, 32, 2, 56, 26, 2, 6, 2, 2, 18, 4, 2, 22, 21, 2, 2, 26, 2, 5, 2, 30, 2, 18, 51, 36, 28, 2, 92, 25, 2, 4, 2, 65, 16, 38, 2, 88, 12, 16, 2, 5, 16, 2, 2, 2, 32, 15, 16, 2, 19, 2, 32])
# ...

# %%
from keras.preprocessing.text import one_hot
#define documents
docs = ['glass of orange juice',
'bottle of mango juice',
'glass of mango shake',
'drink bottle of banana shake',
'I want a glass of cold water',
'The king and the queen',
'man and woman']
vocab_size = 10000
encoded_docs = [one_hot(d, vocab_size) for d in docs]
print(encoded_docs)
# Out:
# [[4589, 1938, 2006, 5934], [1417, 1938, 386, 5934], [4589, 1938, 386, 8424], [5776, 1417, 1938, 5311, 8424], [6039, 4707, 6539, 4589, 1938, 9663, 7309], [2204, 3487, 8895, 2204, 3379], [3236, 8895, 3871]]
